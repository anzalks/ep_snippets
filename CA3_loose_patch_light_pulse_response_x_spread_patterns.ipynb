# %%
# %matplotlib inline
__author__           = "Anzal KS"
__copyright__        = "Copyright 2022-, Anzal KS"
__maintainer__       = "Anzal KS"
__email__            = "anzalks@ncbs.res.in"
from pathlib import Path
import neo.io as nio
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as spy
import pandas

# %%
cell_folder = Path('/Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings')
csv_file = Path('/Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/experiment_notes.csv')
#outdir = cell_folder.parents[0]/'results_plot'
outdir = cell_folder/'results_plot'
outdir.mkdir(exist_ok=True,parents=True)

# %%
"""
file organising fucntions
"""
def list_files(p):
    f_list = []
    f_list=list(p.glob('**/*abf'))
    f_list.sort()
    return f_list

def find_csv(c):
    csv_file = str(c)
    csv_file = pandas.read_csv(csv_file,header=1)
    return(csv_file)

# %%
abf_files = list_files(cell_folder)
cell_data = find_csv(csv_file)

# %%
"""
assign cell and experiment data to files
"""
def expt_cell_assigner():
    cells = cell_data['cell_ID']
    cell_expt_data = []
    for cell in cells:
        cell_expt_data.append(cell_data[cell_data['cell_ID']==cell])
    print(cell_expt_data)

# %%
"""
extra functions
"""

"""
smoothening function
"""
def smooth(data, kernel_size):
    '''apply a smoothing kernel of length kernel_size to 1D data
    '''
    kernel = np.ones(kernel_size) / kernel_size
    return np.convolve(data, kernel, mode='same')



"""
data filter function
"""
def filter_data(data, cutoff, filt_type, fs, order=3):
    '''
    creates and applies a filter
    '''
    b, a = spy.butter(order, cutoff, btype = filt_type, analog=False, output='ba', fs=fs)
    return spy.filtfilt(b, a, data)
    """
    b, a = spy.butter(order, cutoff, analog=False, output='ba', fs=fs)
    return spy.filtfilt(b, a, data)
    """

def downsampling_funct(d_array, initial_fs, final_fs):
    """
    down sampling function
    downsampling from 32 khz to 1khz
    initial_fs = initial smapling rate
    final_fs = final sampling rate
    1_d_array = 1 d rray with samples(ep_single channel data)
    """
    downsampling_factor = np.floor(initial_fs/final_fs)
    dat_idx = np.arange(0,len(d_array), downsampling_factor).astype(np.int32)
    ds_dat = d_array[dat_idx]
    return ds_dat

def butter_bandpass(lowcut, highcut, fs, order=5):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq
    b, a = spy.butter(N=order, Wn=[low, high], btype='bandpass')
    return b, a


def butter_bandpass_filter(data, lowcut, highcut, fs, order=5):
    b, a = butter_bandpass(lowcut, highcut, fs, order=order)
    y = spy.lfilter(b, a, data)
    return y

# %%
"""
plot 3 pattern responses, extreme left, middle and right end
"""

def plot_select_patterns(f,outdir,p_no):
    f_plt = f'{outdir}/{f.stem}'
    cell_info =cell_data[cell_data['file_name']==f'{f.stem}.abf']
    expt_details = cell_info.to_string(index=False)
    cell_id = cell_info['cell_ID'].to_string(index=False,header=False)
    if 'cell' in cell_id:
        print(f'the cell id = {cell_id}')
    else:
        cell_id = 'non_categorised'
    f_plt_pat = outdir/cell_id
    f_plt_pat.mkdir(exist_ok=True,parents=True)
    f_plt_pat=f_plt_pat/f'{f.stem}_pattern_'
    expt_details = cell_data[cell_data['file_name']==f'{f.stem}.abf'].to_string(index=False)
    file_name = f'{f.stem}'
    f=str(f)
    reader = nio.AxonIO(f)
    channels = reader.header['signal_channels']
    chan_count = len(channels)
    block  = reader.read_block(signal_group_mode='split-all')
    segments = block.segments
    sample_trace = segments[0].analogsignals[0]
    sampling_rate = sample_trace.sampling_rate
    ti = sample_trace.t_start
    tf = sample_trace.t_stop
    total_time = int(tf-ti)
    protocol_raw = reader.read_raw_protocol()
    protocol_raw = protocol_raw[0]
    #print(total_time)
    unit = str(sample_trace.units).split()[1]
    #        print(unit)
    fig, axs = plt.subplots(2,1,figsize=(8,6),sharex='col')
    for i in range(chan_count):
        trace_average = []
        for s, segment in enumerate(segments):
            analogsignals = segment.analogsignals[i]
            unit = str(analogsignals.units).split()[1]
            if unit =='mV':
                unit ='mV'
            elif unit =='pA':
                unit ='pA'
            else:
                unit='Signal amplitude'
                    
            trace = np.array(analogsignals)
            #trace = smooth(trace, 4)
            #trace  = downsampling_funct(trace, int(sampling_rate), 2000)
            trace_average.append(trace)
            #    print(f'length of trace = {len(trace)}')
            t = np.linspace(0,float(tf-ti),len(trace))
            #downsampling_funct(t, int(sampling_rate), 2000)
            if i ==0:
                axs[0].plot(t,trace,alpha=0.7,linewidth=2, label = f'trial - {s+1}')
                axs[0].set_title('recording')
                axs[0].set_ylabel(unit)
            if i ==2:
                axs[1].plot(t,trace,alpha=0.7,linewidth=2, label = f'trial - {s+1}')
                axs[1].set_xlabel('time(s)')
        if i ==0:
            trace_average = np.mean(trace_average,axis=0)
            axs[i].plot(t,trace_average,linewidth=1,color='k', label = f'average')
    if p_no == 0:
        p_no =3
        axs[0].set_xlim(3.105,3.15) #1st pulse
        fig.suptitle(f'{file_name}_pattern_{p_no}')
        plt.xlabel('time (s)',loc='center')
        f_plt_pat = f'{f_plt_pat}_{p_no}.jpg'
        print(f'saved the plot to {f_plt_pat}_{p_no}.jpg')
    elif p_no == 1:
        p_no =4
        axs[0].set_xlim(4.105,4.15) #middle pulse
        fig.suptitle(f'{file_name}_pattern_{p_no}')
        plt.xlabel('time (s)',loc='center')
        f_plt_pat = f'{f_plt_pat}_{p_no}.jpg'
        print(f'saved the plot to {f_plt_pat}_{p_no}.jpg')
    elif p_no == 2:
        p_no =5
        axs[0].set_xlim(5.105,5.15) #last pulse
        fig.suptitle(f'{file_name}_pattern_{p_no}')
        plt.xlabel('time (s)',loc='center')
        f_plt_pat = f'{f_plt_pat}_{p_no}.jpg'
        print(f'saved the plot to {f_plt_pat}_{p_no}.jpg')
    else:
        print(f'saving file {file_name} to plot_failed')
    plt.text(0.2, -0.2, expt_details, fontsize=11, transform=plt.gcf().transFigure)
    fig.savefig(f'{f_plt_pat}',bbox_inches='tight')
    plt.close(fig)

# %%
"""
plot all pattern responses
"""

def plot_all_patterns(f,outdir):
    cell_info =cell_data[cell_data['file_name']==f'{f.stem}.abf']
    expt_details = cell_info.to_string(index=False)
    cell_id = cell_info['cell_ID'].to_string(index=False,header=False)
    if 'cell' in cell_id:
        print(f'cell id = {cell_id}')
    else:
        cell_id = 'non_categorised'
    f_plt = outdir/cell_id
    f_plt.mkdir(exist_ok=True,parents=True)
    f_plt=f_plt/f'{f.stem}.jpg'
    file_name = f'{f.stem}'
    f=str(f)
    reader = nio.AxonIO(f)
    channels = reader.header['signal_channels']
    chan_count = len(channels)
    block  = reader.read_block(signal_group_mode='split-all')
    segments = block.segments
    sample_trace = segments[0].analogsignals[0]
    sampling_rate = sample_trace.sampling_rate
    ti = sample_trace.t_start
    tf = sample_trace.t_stop
    total_time = int(tf-ti)
    protocol_raw = reader.read_raw_protocol()
    protocol_raw = protocol_raw[0]
    #print(total_time)
    unit = str(sample_trace.units).split()[1]
    #        print(unit)
    fig, axs = plt.subplots(2,1,figsize=(12,3),sharex='col')
    for i in range(chan_count):
        trace_average = []
        for s, segment in enumerate(segments):
            analogsignals = segment.analogsignals[i]
            unit = str(analogsignals.units).split()[1]
            if unit =='mV':
                unit ='mV'
            elif unit =='pA':
                unit ='pA'
            else:
                unit='Signal amplitude'
                    
            trace = np.array(analogsignals)
            #trace = smooth(trace, 4)
            #trace  = downsampling_funct(trace, int(sampling_rate), 2000)
            trace_average.append(trace)
            #    print(f'length of trace = {len(trace)}')
            t = np.linspace(0,float(tf-ti),len(trace))
            #downsampling_funct(t, int(sampling_rate), 2000)
            if i ==0:
                axs[0].plot(t,trace,alpha=0.7,linewidth=2, label = f'trial - {s+1}')
                axs[0].set_title('recording')
                axs[0].set_ylabel(unit)
            if i ==2:
                axs[1].plot(t,trace,alpha=0.7,linewidth=2, label = f'trial - {s+1}')
                axs[1].set_xlabel('time(s)')
        if i ==0:
            trace_average = np.mean(trace_average,axis=0)
            axs[i].plot(t,trace_average,linewidth=1,color='k', label = f'average')

    axs[0].set_xlim(0.9,7.2) #last pulse
    plt.text(0.2, -0.2, expt_details, fontsize=11, transform=plt.gcf().transFigure)
    fig.suptitle(file_name)
    plt.xlabel('time (s)',loc='center')
    fig.savefig(f_plt,bbox_inches='tight')
    print(f'saved the plot to {f_plt}')
    plt.close(fig)

# %%
for abf in abf_files:
    plot_all_patterns(abf,outdir)
    for s in range(3):
        try:
            print(f'plotting pattern {s} in file {abf.stem}')
            plot_select_patterns(abf,outdir,s)
            print(f'saved file {abf.stem}')
        except:
            continue
# Out:
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0000.jpg
# plotting pattern 0 in file 2022_11_21_0000
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0000_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0000
# plotting pattern 1 in file 2022_11_21_0000
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0000_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0000
# plotting pattern 2 in file 2022_11_21_0000
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0000_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0000
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0001.jpg
# plotting pattern 0 in file 2022_11_21_0001
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0001_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0001
# plotting pattern 1 in file 2022_11_21_0001
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0001_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0001
# plotting pattern 2 in file 2022_11_21_0001
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0001_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0001
# cell id = 2022_11_21_cell_1
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_1/2022_11_21_0002.jpg
# plotting pattern 0 in file 2022_11_21_0002
# the cell id = 2022_11_21_cell_1
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_1/2022_11_21_0002_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0002
# plotting pattern 1 in file 2022_11_21_0002
# the cell id = 2022_11_21_cell_1
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_1/2022_11_21_0002_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0002
# plotting pattern 2 in file 2022_11_21_0002
# the cell id = 2022_11_21_cell_1
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_1/2022_11_21_0002_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0002
# cell id = 2022_11_21_cell_2
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_2/2022_11_21_0003.jpg
# plotting pattern 0 in file 2022_11_21_0003
# the cell id = 2022_11_21_cell_2
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_2/2022_11_21_0003_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0003
# plotting pattern 1 in file 2022_11_21_0003
# the cell id = 2022_11_21_cell_2
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_2/2022_11_21_0003_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0003
# plotting pattern 2 in file 2022_11_21_0003
# the cell id = 2022_11_21_cell_2
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_2/2022_11_21_0003_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0003
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0004.jpg
# plotting pattern 0 in file 2022_11_21_0004
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0004_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0004
# plotting pattern 1 in file 2022_11_21_0004
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0004_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0004
# plotting pattern 2 in file 2022_11_21_0004
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0004_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0004
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0005.jpg
# plotting pattern 0 in file 2022_11_21_0005
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0005_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0005
# plotting pattern 1 in file 2022_11_21_0005
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0005_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0005
# plotting pattern 2 in file 2022_11_21_0005
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0005_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0005
# cell id = 2022_11_21_cell_3
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_3/2022_11_21_0006.jpg
# plotting pattern 0 in file 2022_11_21_0006
# the cell id = 2022_11_21_cell_3
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_3/2022_11_21_0006_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0006
# plotting pattern 1 in file 2022_11_21_0006
# the cell id = 2022_11_21_cell_3
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_3/2022_11_21_0006_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0006
# plotting pattern 2 in file 2022_11_21_0006
# the cell id = 2022_11_21_cell_3
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_3/2022_11_21_0006_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0006
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0007.jpg
# plotting pattern 0 in file 2022_11_21_0007
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0007_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0007
# plotting pattern 1 in file 2022_11_21_0007
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0007_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0007
# plotting pattern 2 in file 2022_11_21_0007
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0007_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0007
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0008.jpg
# plotting pattern 0 in file 2022_11_21_0008
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0008_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0008
# plotting pattern 1 in file 2022_11_21_0008
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0008_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0008
# plotting pattern 2 in file 2022_11_21_0008
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0008_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0008
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0009.jpg
# plotting pattern 0 in file 2022_11_21_0009
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0009_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0009
# plotting pattern 1 in file 2022_11_21_0009
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0009_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0009
# plotting pattern 2 in file 2022_11_21_0009
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0009_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0009
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0010.jpg
# plotting pattern 0 in file 2022_11_21_0010
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0010_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0010
# plotting pattern 1 in file 2022_11_21_0010
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0010_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0010
# plotting pattern 2 in file 2022_11_21_0010
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0010_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0010
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0011.jpg
# plotting pattern 0 in file 2022_11_21_0011
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0011_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0011
# plotting pattern 1 in file 2022_11_21_0011
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0011_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0011
# plotting pattern 2 in file 2022_11_21_0011
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0011_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0011
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0012.jpg
# plotting pattern 0 in file 2022_11_21_0012
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0012_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0012
# plotting pattern 1 in file 2022_11_21_0012
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0012_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0012
# plotting pattern 2 in file 2022_11_21_0012
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0012_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0012
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0013.jpg
# plotting pattern 0 in file 2022_11_21_0013
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0013_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0013
# plotting pattern 1 in file 2022_11_21_0013
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0013_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0013
# plotting pattern 2 in file 2022_11_21_0013
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0013_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0013
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0014.jpg
# plotting pattern 0 in file 2022_11_21_0014
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0014_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0014
# plotting pattern 1 in file 2022_11_21_0014
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0014_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0014
# plotting pattern 2 in file 2022_11_21_0014
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0014_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0014
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0015.jpg
# plotting pattern 0 in file 2022_11_21_0015
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0015_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0015
# plotting pattern 1 in file 2022_11_21_0015
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0015_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0015
# plotting pattern 2 in file 2022_11_21_0015
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0015_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0015
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0016.jpg
# plotting pattern 0 in file 2022_11_21_0016
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0016_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0016
# plotting pattern 1 in file 2022_11_21_0016
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0016_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0016
# plotting pattern 2 in file 2022_11_21_0016
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0016_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0016
# cell id = 2022_11_21_cell_4
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_4/2022_11_21_0017.jpg
# plotting pattern 0 in file 2022_11_21_0017
# the cell id = 2022_11_21_cell_4
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_4/2022_11_21_0017_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0017
# plotting pattern 1 in file 2022_11_21_0017
# the cell id = 2022_11_21_cell_4
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_4/2022_11_21_0017_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0017
# plotting pattern 2 in file 2022_11_21_0017
# the cell id = 2022_11_21_cell_4
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_4/2022_11_21_0017_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0017
# cell id = 2022_11_21_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_5/2022_11_21_0018.jpg
# plotting pattern 0 in file 2022_11_21_0018
# the cell id = 2022_11_21_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_5/2022_11_21_0018_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0018
# plotting pattern 1 in file 2022_11_21_0018
# the cell id = 2022_11_21_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_5/2022_11_21_0018_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0018
# plotting pattern 2 in file 2022_11_21_0018
# the cell id = 2022_11_21_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_5/2022_11_21_0018_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0018
# cell id = 2022_11_21_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_6/2022_11_21_0019.jpg
# plotting pattern 0 in file 2022_11_21_0019
# the cell id = 2022_11_21_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_6/2022_11_21_0019_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0019
# plotting pattern 1 in file 2022_11_21_0019
# the cell id = 2022_11_21_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_6/2022_11_21_0019_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0019
# plotting pattern 2 in file 2022_11_21_0019
# the cell id = 2022_11_21_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_6/2022_11_21_0019_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0019
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0020.jpg
# plotting pattern 0 in file 2022_11_21_0020
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0020_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0020
# plotting pattern 1 in file 2022_11_21_0020
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0020_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0020
# plotting pattern 2 in file 2022_11_21_0020
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0020_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0020
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0021.jpg
# plotting pattern 0 in file 2022_11_21_0021
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0021_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0021
# plotting pattern 1 in file 2022_11_21_0021
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0021_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0021
# plotting pattern 2 in file 2022_11_21_0021
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0021_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0021
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0022.jpg
# plotting pattern 0 in file 2022_11_21_0022
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0022_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0022
# plotting pattern 1 in file 2022_11_21_0022
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0022_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0022
# plotting pattern 2 in file 2022_11_21_0022
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0022_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0022
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0023.jpg
# plotting pattern 0 in file 2022_11_21_0023
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0023_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0023
# plotting pattern 1 in file 2022_11_21_0023
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0023_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0023
# plotting pattern 2 in file 2022_11_21_0023
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0023_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0023
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0024.jpg
# plotting pattern 0 in file 2022_11_21_0024
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0024_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0024
# plotting pattern 1 in file 2022_11_21_0024
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0024_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0024
# plotting pattern 2 in file 2022_11_21_0024
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0024_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0024
# cell id = 2022_11_21_cell_7
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_7/2022_11_21_0025.jpg
# plotting pattern 0 in file 2022_11_21_0025
# the cell id = 2022_11_21_cell_7
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_7/2022_11_21_0025_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0025
# plotting pattern 1 in file 2022_11_21_0025
# the cell id = 2022_11_21_cell_7
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_7/2022_11_21_0025_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0025
# plotting pattern 2 in file 2022_11_21_0025
# the cell id = 2022_11_21_cell_7
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_7/2022_11_21_0025_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0025
# cell id = 2022_11_21_cell_8
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_8/2022_11_21_0026.jpg
# plotting pattern 0 in file 2022_11_21_0026
# the cell id = 2022_11_21_cell_8
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_8/2022_11_21_0026_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0026
# plotting pattern 1 in file 2022_11_21_0026
# the cell id = 2022_11_21_cell_8
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_8/2022_11_21_0026_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0026
# plotting pattern 2 in file 2022_11_21_0026
# the cell id = 2022_11_21_cell_8
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_8/2022_11_21_0026_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0026
# cell id = 2022_11_21_cell_8
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_8/2022_11_21_0027.jpg
# plotting pattern 0 in file 2022_11_21_0027
# the cell id = 2022_11_21_cell_8
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_8/2022_11_21_0027_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0027
# plotting pattern 1 in file 2022_11_21_0027
# the cell id = 2022_11_21_cell_8
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_8/2022_11_21_0027_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0027
# plotting pattern 2 in file 2022_11_21_0027
# the cell id = 2022_11_21_cell_8
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_8/2022_11_21_0027_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0027
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0028.jpg
# plotting pattern 0 in file 2022_11_21_0028
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0028_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0028
# plotting pattern 1 in file 2022_11_21_0028
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0028_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0028
# plotting pattern 2 in file 2022_11_21_0028
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0028_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0028
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0029.jpg
# plotting pattern 0 in file 2022_11_21_0029
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0029_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0029
# plotting pattern 1 in file 2022_11_21_0029
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0029_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0029
# plotting pattern 2 in file 2022_11_21_0029
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0029_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0029
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0030.jpg
# plotting pattern 0 in file 2022_11_21_0030
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0030_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0030
# plotting pattern 1 in file 2022_11_21_0030
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0030_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0030
# plotting pattern 2 in file 2022_11_21_0030
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0030_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0030
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0031.jpg
# plotting pattern 0 in file 2022_11_21_0031
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0031_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0031
# plotting pattern 1 in file 2022_11_21_0031
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0031_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0031
# plotting pattern 2 in file 2022_11_21_0031
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0031_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0031
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0032.jpg
# plotting pattern 0 in file 2022_11_21_0032
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0032_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0032
# plotting pattern 1 in file 2022_11_21_0032
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0032_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0032
# plotting pattern 2 in file 2022_11_21_0032
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0032_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0032
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0033.jpg
# plotting pattern 0 in file 2022_11_21_0033
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0033_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0033
# plotting pattern 1 in file 2022_11_21_0033
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0033_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0033
# plotting pattern 2 in file 2022_11_21_0033
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0033_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0033
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0034.jpg
# plotting pattern 0 in file 2022_11_21_0034
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0034_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0034
# plotting pattern 1 in file 2022_11_21_0034
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0034_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0034
# plotting pattern 2 in file 2022_11_21_0034
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0034_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0034
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0035.jpg
# plotting pattern 0 in file 2022_11_21_0035
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0035_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0035
# plotting pattern 1 in file 2022_11_21_0035
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0035_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0035
# plotting pattern 2 in file 2022_11_21_0035
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0035_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0035
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0036.jpg
# plotting pattern 0 in file 2022_11_21_0036
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0036_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0036
# plotting pattern 1 in file 2022_11_21_0036
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0036_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0036
# plotting pattern 2 in file 2022_11_21_0036
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0036_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0036
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0037.jpg
# plotting pattern 0 in file 2022_11_21_0037
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0037_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0037
# plotting pattern 1 in file 2022_11_21_0037
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0037_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0037
# plotting pattern 2 in file 2022_11_21_0037
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0037_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0037
# cell id = 2022_11_21_cell_9
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_9/2022_11_21_0038.jpg
# plotting pattern 0 in file 2022_11_21_0038
# the cell id = 2022_11_21_cell_9
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_9/2022_11_21_0038_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0038
# plotting pattern 1 in file 2022_11_21_0038
# the cell id = 2022_11_21_cell_9
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_9/2022_11_21_0038_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0038
# plotting pattern 2 in file 2022_11_21_0038
# the cell id = 2022_11_21_cell_9
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_9/2022_11_21_0038_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0038
# cell id = 2022_11_21_cell_10
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_10/2022_11_21_0039.jpg
# plotting pattern 0 in file 2022_11_21_0039
# the cell id = 2022_11_21_cell_10
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_10/2022_11_21_0039_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0039
# plotting pattern 1 in file 2022_11_21_0039
# the cell id = 2022_11_21_cell_10
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_10/2022_11_21_0039_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0039
# plotting pattern 2 in file 2022_11_21_0039
# the cell id = 2022_11_21_cell_10
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_10/2022_11_21_0039_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0039
# cell id = 2022_11_21_cell_11
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_11/2022_11_21_0040.jpg
# plotting pattern 0 in file 2022_11_21_0040
# the cell id = 2022_11_21_cell_11
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_11/2022_11_21_0040_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0040
# plotting pattern 1 in file 2022_11_21_0040
# the cell id = 2022_11_21_cell_11
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_11/2022_11_21_0040_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0040
# plotting pattern 2 in file 2022_11_21_0040
# the cell id = 2022_11_21_cell_11
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_11/2022_11_21_0040_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0040
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0041.jpg
# plotting pattern 0 in file 2022_11_21_0041
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0041_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0041
# plotting pattern 1 in file 2022_11_21_0041
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0041_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0041
# plotting pattern 2 in file 2022_11_21_0041
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0041_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0041
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0042.jpg
# plotting pattern 0 in file 2022_11_21_0042
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0042_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0042
# plotting pattern 1 in file 2022_11_21_0042
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0042_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0042
# plotting pattern 2 in file 2022_11_21_0042
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0042_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0042
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0043.jpg
# plotting pattern 0 in file 2022_11_21_0043
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0043_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0043
# plotting pattern 1 in file 2022_11_21_0043
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0043_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0043
# plotting pattern 2 in file 2022_11_21_0043
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0043_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0043
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0044.jpg
# plotting pattern 0 in file 2022_11_21_0044
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0044_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0044
# plotting pattern 1 in file 2022_11_21_0044
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0044_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0044
# plotting pattern 2 in file 2022_11_21_0044
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0044_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0044
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0045.jpg
# plotting pattern 0 in file 2022_11_21_0045
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0045_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0045
# plotting pattern 1 in file 2022_11_21_0045
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0045_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0045
# plotting pattern 2 in file 2022_11_21_0045
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0045_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0045
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0046.jpg
# plotting pattern 0 in file 2022_11_21_0046
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0046_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0046
# plotting pattern 1 in file 2022_11_21_0046
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0046_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0046
# plotting pattern 2 in file 2022_11_21_0046
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0046_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0046
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0047.jpg
# plotting pattern 0 in file 2022_11_21_0047
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0047_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0047
# plotting pattern 1 in file 2022_11_21_0047
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0047_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0047
# plotting pattern 2 in file 2022_11_21_0047
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0047_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0047
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0048.jpg
# plotting pattern 0 in file 2022_11_21_0048
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0048_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0048
# plotting pattern 1 in file 2022_11_21_0048
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0048_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0048
# plotting pattern 2 in file 2022_11_21_0048
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0048_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0048
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0049.jpg
# plotting pattern 0 in file 2022_11_21_0049
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0049_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0049
# plotting pattern 1 in file 2022_11_21_0049
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0049_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0049
# plotting pattern 2 in file 2022_11_21_0049
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0049_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0049
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0050.jpg
# plotting pattern 0 in file 2022_11_21_0050
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0050_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0050
# plotting pattern 1 in file 2022_11_21_0050
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0050_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0050
# plotting pattern 2 in file 2022_11_21_0050
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0050_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0050
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0051.jpg
# plotting pattern 0 in file 2022_11_21_0051
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0051_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0051
# plotting pattern 1 in file 2022_11_21_0051
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0051_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0051
# plotting pattern 2 in file 2022_11_21_0051
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0051_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0051
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0052.jpg
# plotting pattern 0 in file 2022_11_21_0052
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0052_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0052
# plotting pattern 1 in file 2022_11_21_0052
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0052_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0052
# plotting pattern 2 in file 2022_11_21_0052
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0052_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0052
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0053.jpg
# plotting pattern 0 in file 2022_11_21_0053
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0053_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0053
# plotting pattern 1 in file 2022_11_21_0053
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0053_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0053
# plotting pattern 2 in file 2022_11_21_0053
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0053_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0053
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0054.jpg
# plotting pattern 0 in file 2022_11_21_0054
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0054_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0054
# plotting pattern 1 in file 2022_11_21_0054
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0054_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0054
# plotting pattern 2 in file 2022_11_21_0054
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0054_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0054
# cell id = 2022_11_21_cell_12
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_12/2022_11_21_0055.jpg
# plotting pattern 0 in file 2022_11_21_0055
# the cell id = 2022_11_21_cell_12
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_12/2022_11_21_0055_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0055
# plotting pattern 1 in file 2022_11_21_0055
# the cell id = 2022_11_21_cell_12
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_12/2022_11_21_0055_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0055
# plotting pattern 2 in file 2022_11_21_0055
# the cell id = 2022_11_21_cell_12
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_12/2022_11_21_0055_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0055
# cell id = 2022_11_21_cell_13
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_13/2022_11_21_0056.jpg
# plotting pattern 0 in file 2022_11_21_0056
# the cell id = 2022_11_21_cell_13
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_13/2022_11_21_0056_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0056
# plotting pattern 1 in file 2022_11_21_0056
# the cell id = 2022_11_21_cell_13
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_13/2022_11_21_0056_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0056
# plotting pattern 2 in file 2022_11_21_0056
# the cell id = 2022_11_21_cell_13
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_13/2022_11_21_0056_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0056
# cell id = 2022_11_21_cell_13
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_13/2022_11_21_0057.jpg
# plotting pattern 0 in file 2022_11_21_0057
# the cell id = 2022_11_21_cell_13
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_13/2022_11_21_0057_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0057
# plotting pattern 1 in file 2022_11_21_0057
# the cell id = 2022_11_21_cell_13
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_13/2022_11_21_0057_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0057
# plotting pattern 2 in file 2022_11_21_0057
# the cell id = 2022_11_21_cell_13
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_13/2022_11_21_0057_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0057
# cell id = 2022_11_21_cell_14
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_14/2022_11_21_0058.jpg
# plotting pattern 0 in file 2022_11_21_0058
# the cell id = 2022_11_21_cell_14
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_14/2022_11_21_0058_pattern__3.jpg_3.jpg
# saved file 2022_11_21_0058
# plotting pattern 1 in file 2022_11_21_0058
# the cell id = 2022_11_21_cell_14
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_14/2022_11_21_0058_pattern__4.jpg_4.jpg
# saved file 2022_11_21_0058
# plotting pattern 2 in file 2022_11_21_0058
# the cell id = 2022_11_21_cell_14
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_21_cell_14/2022_11_21_0058_pattern__5.jpg_5.jpg
# saved file 2022_11_21_0058
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_21_0059.jpg
# plotting pattern 0 in file 2022_11_21_0059
# ...
# plotting pattern 1 in file 2022_11_23_0034
# the cell id = 2022_11_23_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_5/2022_11_23_0034_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0034
# plotting pattern 2 in file 2022_11_23_0034
# the cell id = 2022_11_23_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_5/2022_11_23_0034_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0034
# cell id = 2022_11_23_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_5/2022_11_23_0035.jpg
# plotting pattern 0 in file 2022_11_23_0035
# the cell id = 2022_11_23_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_5/2022_11_23_0035_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0035
# plotting pattern 1 in file 2022_11_23_0035
# the cell id = 2022_11_23_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_5/2022_11_23_0035_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0035
# plotting pattern 2 in file 2022_11_23_0035
# the cell id = 2022_11_23_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_5/2022_11_23_0035_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0035
# cell id = 2022_11_23_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_5/2022_11_23_0036.jpg
# plotting pattern 0 in file 2022_11_23_0036
# the cell id = 2022_11_23_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_5/2022_11_23_0036_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0036
# plotting pattern 1 in file 2022_11_23_0036
# the cell id = 2022_11_23_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_5/2022_11_23_0036_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0036
# plotting pattern 2 in file 2022_11_23_0036
# the cell id = 2022_11_23_cell_5
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_5/2022_11_23_0036_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0036
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0037.jpg
# plotting pattern 0 in file 2022_11_23_0037
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0037_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0037
# plotting pattern 1 in file 2022_11_23_0037
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0037_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0037
# plotting pattern 2 in file 2022_11_23_0037
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0037_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0037
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0038.jpg
# plotting pattern 0 in file 2022_11_23_0038
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0038_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0038
# plotting pattern 1 in file 2022_11_23_0038
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0038_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0038
# plotting pattern 2 in file 2022_11_23_0038
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0038_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0038
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0039.jpg
# plotting pattern 0 in file 2022_11_23_0039
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0039_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0039
# plotting pattern 1 in file 2022_11_23_0039
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0039_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0039
# plotting pattern 2 in file 2022_11_23_0039
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0039_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0039
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0040.jpg
# plotting pattern 0 in file 2022_11_23_0040
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0040_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0040
# plotting pattern 1 in file 2022_11_23_0040
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0040_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0040
# plotting pattern 2 in file 2022_11_23_0040
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0040_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0040
# cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0041.jpg
# plotting pattern 0 in file 2022_11_23_0041
# the cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0041_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0041
# plotting pattern 1 in file 2022_11_23_0041
# the cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0041_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0041
# plotting pattern 2 in file 2022_11_23_0041
# the cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0041_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0041
# cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0042.jpg
# plotting pattern 0 in file 2022_11_23_0042
# the cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0042_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0042
# plotting pattern 1 in file 2022_11_23_0042
# the cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0042_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0042
# plotting pattern 2 in file 2022_11_23_0042
# the cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0042_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0042
# cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0043.jpg
# plotting pattern 0 in file 2022_11_23_0043
# the cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0043_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0043
# plotting pattern 1 in file 2022_11_23_0043
# the cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0043_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0043
# plotting pattern 2 in file 2022_11_23_0043
# the cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0043_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0043
# cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0044.jpg
# plotting pattern 0 in file 2022_11_23_0044
# the cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0044_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0044
# plotting pattern 1 in file 2022_11_23_0044
# the cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0044_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0044
# plotting pattern 2 in file 2022_11_23_0044
# the cell id = 2022_11_23_cell_6
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/2022_11_23_cell_6/2022_11_23_0044_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0044
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0045.jpg
# plotting pattern 0 in file 2022_11_23_0045
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0045_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0045
# plotting pattern 1 in file 2022_11_23_0045
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0045_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0045
# plotting pattern 2 in file 2022_11_23_0045
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0045_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0045
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0046.jpg
# plotting pattern 0 in file 2022_11_23_0046
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0046_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0046
# plotting pattern 1 in file 2022_11_23_0046
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0046_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0046
# plotting pattern 2 in file 2022_11_23_0046
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0046_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0046
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0047.jpg
# plotting pattern 0 in file 2022_11_23_0047
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0047_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0047
# plotting pattern 1 in file 2022_11_23_0047
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0047_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0047
# plotting pattern 2 in file 2022_11_23_0047
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0047_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0047
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0048.jpg
# plotting pattern 0 in file 2022_11_23_0048
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0048_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0048
# plotting pattern 1 in file 2022_11_23_0048
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0048_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0048
# plotting pattern 2 in file 2022_11_23_0048
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0048_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0048
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0049.jpg
# plotting pattern 0 in file 2022_11_23_0049
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0049_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0049
# plotting pattern 1 in file 2022_11_23_0049
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0049_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0049
# plotting pattern 2 in file 2022_11_23_0049
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0049_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0049
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0050.jpg
# plotting pattern 0 in file 2022_11_23_0050
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0050_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0050
# plotting pattern 1 in file 2022_11_23_0050
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0050_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0050
# plotting pattern 2 in file 2022_11_23_0050
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0050_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0050
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0051.jpg
# plotting pattern 0 in file 2022_11_23_0051
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0051_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0051
# plotting pattern 1 in file 2022_11_23_0051
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0051_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0051
# plotting pattern 2 in file 2022_11_23_0051
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0051_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0051
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0052.jpg
# plotting pattern 0 in file 2022_11_23_0052
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0052_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0052
# plotting pattern 1 in file 2022_11_23_0052
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0052_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0052
# plotting pattern 2 in file 2022_11_23_0052
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0052_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0052
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0053.jpg
# plotting pattern 0 in file 2022_11_23_0053
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0053_pattern__3.jpg_3.jpg
# saved file 2022_11_23_0053
# plotting pattern 1 in file 2022_11_23_0053
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0053_pattern__4.jpg_4.jpg
# saved file 2022_11_23_0053
# plotting pattern 2 in file 2022_11_23_0053
# saved the plot to /Users/anzalks/Documents/Expt_data/Recordings/CA3_recordings/results_plot/non_categorised/2022_11_23_0053_pattern__5.jpg_5.jpg
# saved file 2022_11_23_0053
